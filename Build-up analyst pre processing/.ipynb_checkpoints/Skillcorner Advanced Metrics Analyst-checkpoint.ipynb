# %%
import os
import pandas as pd

folder_path = r"..\data\dynamic_events_pl_24"

# List all parquet files
files = [f for f in os.listdir(folder_path) if f.lower().endswith(".parquet")]
print("Parquet files found:", files)

for filename in files:
    file_path = os.path.join(folder_path, filename)
    df_name = os.path.splitext(filename)[0]  # remove .parquet extension
    try:
        globals()[df_name] = pd.read_parquet(file_path)
        print(f"DataFrame '{df_name}' created with shape {globals()[df_name].shape}")
    except Exception as e:
        print(f"Error reading {filename}: {e}")
# Out:
# Parquet files found: ['matches.parquet', 'players.parquet', 'teams.parquet']
# DataFrame 'matches' created with shape (380, 8)
# DataFrame 'players' created with shape (686, 7)
# DataFrame 'teams' created with shape (20, 4)

# %%
# Expand 'home_team' and 'away_team' dictionaries
home_df = pd.json_normalize(matches['home_team']).add_prefix('home_')
away_df = pd.json_normalize(matches['away_team']).add_prefix('away_')

# Drop the original dict columns and concatenate the new ones
matches_expanded = pd.concat([matches.drop(['home_team', 'away_team'], axis=1), home_df, away_df], axis=1)

matches_expanded.head()
# Out:
#         id             date_time  status  competition_id  season_id  \
# 0  2018571  2025-05-25T15:00:00Z  closed               1         95
# 1  2018572  2025-05-25T15:00:00Z  closed               1         95
# 2  2018573  2025-05-25T15:00:00Z  closed               1         95
# 3  2018574  2025-05-25T15:00:00Z  closed               1         95
# 4  2018575  2025-05-25T15:00:00Z  closed               1         95
#
#    competition_edition_id  home_id home_short_name  away_id  away_short_name
# 0                     895       63     Bournemouth       62        Leicester
# 1                     895       48          Fulham       40  Manchester City
# 2                     895      752    Ipswich Town       37         West Ham
# 3                     895        2       Liverpool       60   Crystal Palace
# 4                     895       31    Manchester U       39      Aston Villa

# %%
players.head()
# Out:
#        id   first_name   last_name     short_name    birthday  \
# 0   18589          Max      Aarons      M. Aarons  2000-01-04
# 1  967750         Zach      Abbott      Z. Abbott  2006-05-13
# 2  514681  Joshua Kofi  Acheampong  J. Acheampong  2006-05-05
# 3   24629        Tyler       Adams       T. Adams  1999-02-14
# 4   11589   Oluwatosin  Adarabioyo  T. Adarabioyo  1997-09-24
#
#    trackable_object gender
# 0             18786   male
# 1            969313   male
# 2            516238   male
# 3             25664   male
# 4             11670   male

# %%
# Expand the 'stadium' dictionary
stadium_df = pd.json_normalize(teams['stadium']).add_prefix('stadium_')

# Drop the original 'stadium' column and concatenate the new ones
teams_expanded = pd.concat([teams.drop('stadium', axis=1), stadium_df], axis=1)

teams_expanded.head()
# Out:
#     id               name coach  stadium_capacity stadium_city  stadium_id  \
# 0   39        Aston Villa  None           42682.0   Birmingham         488
# 1  754       Brentford FC  None               NaN       London        1970
# 2   37    West Ham United  None           60000.0       London          52
# 3   31  Manchester United  None           75635.0   Manchester          63
# 4   41            Everton  None           39571.0    Liverpool          89
#
#                   stadium_name
# 0                   Villa Park
# 1  Brentford Community Stadium
# 2   Stade Olympique de Londres
# 3                 Old Trafford
# 4                Goodison Park

# %%
import os
import pandas as pd

# Base folder (relative path like your working script)
base_folder = r"..\data\dynamic_events_pl_24"

# Folders to read
folders = ["dynamic", "meta"]

for folder in folders:
    folder_path = os.path.join(base_folder, folder)

    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        continue

    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith(".parquet"):
                file_path = os.path.join(root, filename)

                df_name = os.path.splitext(filename)[0]
                df_name = df_name.replace(" ", "_").replace("-", "_")

                try:
                    globals()[df_name] = pd.read_parquet(file_path)
                    print(f"Loaded {df_name} with shape {globals()[df_name].shape}")
                except Exception as e:
                    print(f"Error reading {filename}: {e}")
# Out:
# Loaded 1650385 with shape (4864, 294)
# Loaded 1650961 with shape (4769, 294)
# Loaded 1651700 with shape (4181, 294)
# Loaded 1651701 with shape (4371, 294)
# Loaded 1651702 with shape (4762, 294)
# Loaded 1651703 with shape (4533, 294)
# Loaded 1653146 with shape (4441, 294)
# Loaded 1654741 with shape (5476, 294)
# Loaded 1657085 with shape (5078, 294)
# Loaded 1666058 with shape (5183, 294)
# Loaded 1666917 with shape (4656, 294)
# Loaded 1666918 with shape (4503, 294)
# Loaded 1666919 with shape (5223, 294)
# Loaded 1666920 with shape (5041, 294)
# Loaded 1666921 with shape (4948, 294)
# Loaded 1666922 with shape (4786, 294)
# Loaded 1668692 with shape (4380, 294)
# Loaded 1669604 with shape (5272, 294)
# Loaded 1669605 with shape (4437, 294)
# Loaded 1680834 with shape (4489, 294)
# Loaded 1680836 with shape (5224, 294)
# Loaded 1680837 with shape (4101, 294)
# Loaded 1681563 with shape (5509, 294)
# Loaded 1681564 with shape (3839, 294)
# Loaded 1681565 with shape (4736, 294)
# Loaded 1681566 with shape (3990, 294)
# Loaded 1683027 with shape (5050, 294)
# Loaded 1683028 with shape (4218, 294)
# Loaded 1683029 with shape (4813, 294)
# Loaded 1711918 with shape (4236, 294)
# Loaded 1711920 with shape (4438, 294)
# Loaded 1711921 with shape (5572, 294)
# Loaded 1712846 with shape (4467, 294)
# Loaded 1712847 with shape (4874, 294)
# Loaded 1712849 with shape (4400, 294)
# Loaded 1712850 with shape (4423, 294)
# Loaded 1713834 with shape (5371, 294)
# Loaded 1715919 with shape (4817, 294)
# Loaded 1715920 with shape (4329, 294)
# Loaded 1729513 with shape (5090, 294)
# Loaded 1729514 with shape (4715, 294)
# Loaded 1729515 with shape (4703, 294)
# Loaded 1729516 with shape (5108, 294)
# Loaded 1729517 with shape (4338, 294)
# Loaded 1729518 with shape (4793, 294)
# Loaded 1729520 with shape (4794, 294)
# Loaded 1730528 with shape (4457, 294)
# Loaded 1732598 with shape (5195, 294)
# Loaded 1732599 with shape (4370, 294)
# Loaded 1747407 with shape (4574, 294)
# Loaded 1747409 with shape (4933, 294)
# Loaded 1747410 with shape (4858, 294)
# Loaded 1747411 with shape (4985, 294)
# Loaded 1747412 with shape (4844, 294)
# Loaded 1748494 with shape (5214, 294)
# Loaded 1748495 with shape (4547, 294)
# Loaded 1750708 with shape (5003, 294)
# Loaded 1751820 with shape (5444, 294)
# Loaded 1755069 with shape (5138, 294)
# Loaded 1766002 with shape (4862, 294)
# Loaded 1766988 with shape (5076, 294)
# Loaded 1766989 with shape (5031, 294)
# Loaded 1766990 with shape (5665, 294)
# Loaded 1766991 with shape (4324, 294)
# Loaded 1766992 with shape (4392, 294)
# Loaded 1766993 with shape (4875, 294)
# Loaded 1770288 with shape (4573, 294)
# Loaded 1770289 with shape (4375, 294)
# Loaded 1770290 with shape (4672, 294)
# Loaded 1799222 with shape (4689, 294)
# Loaded 1799223 with shape (4540, 294)
# Loaded 1800187 with shape (4568, 294)
# Loaded 1800188 with shape (4661, 294)
# Loaded 1800189 with shape (4537, 294)
# Loaded 1800190 with shape (4696, 294)
# Loaded 1800191 with shape (5195, 294)
# Loaded 1802141 with shape (4935, 294)
# Loaded 1803128 with shape (4950, 294)
# Loaded 1806021 with shape (4738, 294)
# Loaded 1815119 with shape (4480, 294)
# Loaded 1816810 with shape (5708, 294)
# Loaded 1816811 with shape (4784, 294)
# Loaded 1816812 with shape (4632, 294)
# Loaded 1816813 with shape (4381, 294)
# Loaded 1817721 with shape (4962, 294)
# Loaded 1819620 with shape (4625, 294)
# Loaded 1819621 with shape (5048, 294)
# Loaded 1819622 with shape (4305, 294)
# Loaded 1819623 with shape (4740, 294)
# Loaded 1832248 with shape (4351, 294)
# Loaded 1832948 with shape (4390, 294)
# Loaded 1832949 with shape (4924, 294)
# Loaded 1832950 with shape (4759, 294)
# Loaded 1832951 with shape (4988, 294)
# Loaded 1832952 with shape (4002, 294)
# Loaded 1832953 with shape (5126, 294)
# Loaded 1834552 with shape (4269, 294)
# Loaded 1835431 with shape (4604, 294)
# Loaded 1837900 with shape (5135, 294)
# Loaded 1846872 with shape (4233, 294)
# Loaded 1846873 with shape (5235, 294)
# Loaded 1846874 with shape (4553, 294)
# Loaded 1846875 with shape (4742, 294)
# Loaded 1847630 with shape (5005, 294)
# Loaded 1847631 with shape (5673, 294)
# Loaded 1849276 with shape (4788, 294)
# Loaded 1849277 with shape (5177, 294)
# Loaded 1849278 with shape (4705, 294)
# Loaded 1849279 with shape (4588, 294)
# Loaded 1873885 with shape (4985, 294)
# Loaded 1873886 with shape (4781, 294)
# Loaded 1873888 with shape (4575, 294)
# Loaded 1873889 with shape (5210, 294)
# Loaded 1873890 with shape (4781, 294)
# Loaded 1874584 with shape (5484, 294)
# Loaded 1874585 with shape (4836, 294)
# Loaded 1876099 with shape (5100, 294)
# Loaded 1876897 with shape (5600, 294)
# Loaded 1879054 with shape (5388, 294)
# Loaded 1886376 with shape (4962, 294)
# Loaded 1887116 with shape (4415, 294)
# Loaded 1887117 with shape (4815, 294)
# Loaded 1887118 with shape (4278, 294)
# Loaded 1887119 with shape (3733, 294)
# Loaded 1887120 with shape (4611, 294)
# Loaded 1888593 with shape (4872, 294)
# Loaded 1889313 with shape (5121, 294)
# Loaded 1889314 with shape (5263, 294)
# Loaded 1889315 with shape (5007, 294)
# Loaded 1893580 with shape (5185, 294)
# Loaded 1893581 with shape (4917, 294)
# Loaded 1895412 with shape (5123, 294)
# Loaded 1895413 with shape (4550, 294)
# Loaded 1895414 with shape (4565, 294)
# Loaded 1895415 with shape (4405, 294)
# Loaded 1895416 with shape (4903, 294)
# Loaded 1895417 with shape (5289, 294)
# Loaded 1897172 with shape (4260, 294)
# Loaded 1897173 with shape (4811, 294)
# Loaded 1900295 with shape (4388, 294)
# Loaded 1900296 with shape (4981, 294)
# Loaded 1900297 with shape (4755, 294)
# Loaded 1900298 with shape (5550, 294)
# Loaded 1901785 with shape (4273, 294)
# Loaded 1901786 with shape (4827, 294)
# Loaded 1902568 with shape (4563, 294)
# Loaded 1903346 with shape (5042, 294)
# Loaded 1904770 with shape (4230, 294)
# Loaded 1912994 with shape (5143, 294)
# Loaded 1912995 with shape (5053, 294)
# Loaded 1912996 with shape (4807, 294)
# Loaded 1912997 with shape (5034, 294)
# Loaded 1912998 with shape (4817, 294)
# Loaded 1915033 with shape (5177, 294)
# Loaded 1915034 with shape (4898, 294)
# Loaded 1915753 with shape (4486, 294)
# Loaded 1915754 with shape (5326, 294)
# Loaded 1917682 with shape (4499, 294)
# Loaded 1925317 with shape (5230, 294)
# Loaded 1925318 with shape (5377, 294)
# Loaded 1925974 with shape (5139, 294)
# Loaded 1925975 with shape (4653, 294)
# Loaded 1925976 with shape (4239, 294)
# Loaded 1927291 with shape (5641, 294)
# Loaded 1927292 with shape (4411, 294)
# Loaded 1927293 with shape (5058, 294)
# Loaded 1927294 with shape (4687, 294)
# Loaded 1927295 with shape (4602, 294)
# Loaded 1934145 with shape (4750, 294)
# Loaded 1934146 with shape (5633, 294)
# Loaded 1934147 with shape (4955, 294)
# Loaded 1934150 with shape (5338, 294)
# Loaded 1934786 with shape (4972, 294)
# Loaded 1934787 with shape (5162, 294)
# Loaded 1934788 with shape (4627, 294)
# Loaded 1934789 with shape (4724, 294)
# Loaded 1936645 with shape (5633, 294)
# Loaded 1936646 with shape (4669, 294)
# Loaded 1939711 with shape (5375, 294)
# Loaded 1939712 with shape (4550, 294)
# Loaded 1939713 with shape (4055, 294)
# Loaded 1939714 with shape (5086, 294)
# Loaded 1939715 with shape (4414, 294)
# Loaded 1939716 with shape (5704, 294)
# Loaded 1941550 with shape (5822, 294)
# Loaded 1941551 with shape (4480, 294)
# Loaded 1941552 with shape (4997, 294)
# Loaded 1945190 with shape (5323, 294)
# Loaded 1949357 with shape (5363, 294)
# Loaded 1949358 with shape (5278, 294)
# Loaded 1949360 with shape (4836, 294)
# Loaded 1949361 with shape (5371, 294)
# Loaded 1949362 with shape (4974, 294)
# Loaded 1949363 with shape (4722, 294)
# Loaded 1951174 with shape (4285, 294)
# Loaded 1951175 with shape (4867, 294)
# Loaded 1951807 with shape (3801, 294)
# Loaded 1953619 with shape (4902, 294)
# Loaded 1966655 with shape (4340, 294)
# Loaded 1967223 with shape (5187, 294)
# Loaded 1967224 with shape (4927, 294)
# Loaded 1967225 with shape (4027, 294)
# Loaded 1968372 with shape (4640, 294)
# Loaded 1968373 with shape (4605, 294)
# Loaded 1968374 with shape (5437, 294)
# Loaded 1968375 with shape (5371, 294)
# Loaded 1969492 with shape (5209, 294)
# Loaded 1970055 with shape (4718, 294)
# Loaded 1972418 with shape (4256, 294)
# Loaded 1972419 with shape (4593, 294)
# Loaded 1972420 with shape (5026, 294)
# Loaded 1972421 with shape (5350, 294)
# Loaded 1972422 with shape (4211, 294)
# Loaded 1974368 with shape (5845, 294)
# Loaded 1974369 with shape (4863, 294)
# Loaded 1974370 with shape (4628, 294)
# Loaded 1974371 with shape (4735, 294)
# Loaded 1976820 with shape (4912, 294)
# Loaded 1985287 with shape (5157, 294)
# Loaded 1985288 with shape (3981, 294)
# Loaded 1985289 with shape (4779, 294)
# Loaded 1985290 with shape (5504, 294)
# Loaded 1985291 with shape (4875, 294)
# Loaded 1985292 with shape (4958, 294)
# Loaded 1986707 with shape (4746, 294)
# Loaded 1986708 with shape (3765, 294)
# Loaded 1986709 with shape (4696, 294)
# Loaded 1987415 with shape (5295, 294)
# Loaded 1997065 with shape (4875, 294)
# Loaded 1997066 with shape (4997, 294)
# Loaded 1997067 with shape (4610, 294)
# Loaded 1997068 with shape (4776, 294)
# Loaded 1997729 with shape (4495, 294)
# Loaded 1999189 with shape (4896, 294)
# Loaded 1999190 with shape (4895, 294)
# Loaded 1999191 with shape (4695, 294)
# Loaded 1999980 with shape (4535, 294)
# Loaded 2001338 with shape (4635, 294)
# Loaded 2003007 with shape (4366, 294)
# Loaded 2003157 with shape (5469, 294)
# Loaded 2003245 with shape (4440, 294)
# Loaded 2003325 with shape (4608, 294)
# Loaded 2003326 with shape (5064, 294)
# Loaded 2003327 with shape (4928, 294)
# Loaded 2003328 with shape (5221, 294)
# Loaded 2003329 with shape (4718, 294)
# Loaded 2003330 with shape (4644, 294)
# Loaded 2003492 with shape (5147, 294)
# Loaded 2003493 with shape (4829, 294)
# Loaded 2003931 with shape (4673, 294)
# Loaded 2004054 with shape (4643, 294)
# Loaded 2004167 with shape (4970, 294)
# Loaded 2004168 with shape (5244, 294)
# Loaded 2004170 with shape (4698, 294)
# Loaded 2004171 with shape (4689, 294)
# Loaded 2004172 with shape (4514, 294)
# Loaded 2004173 with shape (4626, 294)
# Loaded 2004437 with shape (5476, 294)
# Loaded 2004438 with shape (4498, 294)
# Loaded 2004875 with shape (5422, 294)
# Loaded 2004876 with shape (4562, 294)
# Loaded 2004877 with shape (5158, 294)
# Loaded 2004878 with shape (4055, 294)
# Loaded 2004973 with shape (4842, 294)
# Loaded 2004974 with shape (4653, 294)
# Loaded 2005040 with shape (5121, 294)
# Loaded 2005041 with shape (4535, 294)
# Loaded 2005042 with shape (5174, 294)
# Loaded 2005099 with shape (5798, 294)
# Loaded 2006304 with shape (4770, 294)
# Loaded 2006396 with shape (4855, 294)
# Loaded 2006397 with shape (4387, 294)
# Loaded 2006398 with shape (5164, 294)
# Loaded 2006399 with shape (4077, 294)
# Loaded 2006400 with shape (4926, 294)
# Loaded 2006584 with shape (4977, 294)
# Loaded 2006585 with shape (5067, 294)
# Loaded 2006586 with shape (4812, 294)
# Loaded 2006857 with shape (4804, 294)
# Loaded 2007481 with shape (4893, 294)
# Loaded 2007482 with shape (4252, 294)
# Loaded 2007483 with shape (4468, 294)
# Loaded 2007484 with shape (5310, 294)
# Loaded 2007558 with shape (4388, 294)
# Loaded 2007736 with shape (4713, 294)
# Loaded 2007737 with shape (5294, 294)
# Loaded 2007863 with shape (5130, 294)
# Loaded 2009693 with shape (5166, 294)
# Loaded 2009694 with shape (5156, 294)
# Loaded 2009695 with shape (5146, 294)
# Loaded 2009783 with shape (4486, 294)
# Loaded 2009784 with shape (4618, 294)
# Loaded 2009785 with shape (5535, 294)
# Loaded 2009786 with shape (4447, 294)
# Loaded 2009787 with shape (4774, 294)
# Loaded 2009828 with shape (4499, 294)
# Loaded 2009901 with shape (4695, 294)
# Loaded 2010150 with shape (4542, 294)
# Loaded 2010151 with shape (4536, 294)
# Loaded 2010152 with shape (3921, 294)
# Loaded 2010153 with shape (4266, 294)
# Loaded 2010154 with shape (3590, 294)
# Loaded 2010323 with shape (4398, 294)
# Loaded 2010324 with shape (5110, 294)
# Loaded 2010325 with shape (5087, 294)
# Loaded 2010414 with shape (5122, 294)
# Loaded 2010636 with shape (5032, 294)
# Loaded 2011150 with shape (5587, 294)
# Loaded 2011202 with shape (4292, 294)
# Loaded 2011203 with shape (4378, 294)
# Loaded 2011204 with shape (3982, 294)
# Loaded 2011205 with shape (4791, 294)
# Loaded 2011367 with shape (4227, 294)
# Loaded 2011368 with shape (4860, 294)
# Loaded 2011442 with shape (4799, 294)
# Loaded 2011443 with shape (4986, 294)
# Loaded 2011600 with shape (4415, 294)
# Loaded 2011870 with shape (4541, 294)
# Loaded 2012175 with shape (5049, 294)
# Loaded 2012176 with shape (4402, 294)
# Loaded 2012177 with shape (4726, 294)
# Loaded 2012232 with shape (4604, 294)
# Loaded 2012233 with shape (5284, 294)
# Loaded 2012369 with shape (4746, 294)
# Loaded 2012370 with shape (4962, 294)
# Loaded 2012371 with shape (5532, 294)
# Loaded 2012372 with shape (5206, 294)
# Loaded 2012598 with shape (4201, 294)
# Loaded 2012757 with shape (4270, 294)
# Loaded 2012907 with shape (5512, 294)
# Loaded 2013340 with shape (5232, 294)
# Loaded 2013341 with shape (4392, 294)
# Loaded 2013342 with shape (4664, 294)
# Loaded 2013343 with shape (5555, 294)
# Loaded 2013344 with shape (4646, 294)
# Loaded 2013551 with shape (4358, 294)
# Loaded 2013552 with shape (4152, 294)
# Loaded 2014169 with shape (3792, 294)
# Loaded 2014723 with shape (5681, 294)
# Loaded 2014780 with shape (4824, 294)
# Loaded 2014830 with shape (4750, 294)
# Loaded 2014831 with shape (4591, 294)
# Loaded 2014832 with shape (4660, 294)
# Loaded 2014999 with shape (4908, 294)
# Loaded 2015000 with shape (4397, 294)
# Loaded 2015001 with shape (3976, 294)
# Loaded 2015068 with shape (5051, 294)
# Loaded 2015490 with shape (4388, 294)
# Loaded 2016341 with shape (3961, 294)
# Loaded 2016342 with shape (4619, 294)
# Loaded 2016343 with shape (4094, 294)
# Loaded 2016344 with shape (4879, 294)
# Loaded 2016345 with shape (5218, 294)
# Loaded 2016514 with shape (5257, 294)
# Loaded 2016515 with shape (3952, 294)
# Loaded 2016516 with shape (4663, 294)
# Loaded 2016626 with shape (4563, 294)
# Loaded 2016627 with shape (4121, 294)
# Loaded 2017367 with shape (4384, 294)
# Loaded 2017368 with shape (4603, 294)
# Loaded 2017616 with shape (4991, 294)
# Loaded 2017698 with shape (4575, 294)
# Loaded 2017699 with shape (4054, 294)
# Loaded 2017700 with shape (4609, 294)
# Loaded 2017701 with shape (4676, 294)
# Loaded 2017924 with shape (5140, 294)
# Loaded 2018120 with shape (4636, 294)
# Loaded 2018121 with shape (5604, 294)
# Loaded 2018571 with shape (3919, 294)
# Loaded 2018572 with shape (5161, 294)
# Loaded 2018573 with shape (5576, 294)
# Loaded 2018574 with shape (5104, 294)
# Loaded 2018575 with shape (4957, 294)
# Loaded 2018576 with shape (4526, 294)
# Loaded 2018577 with shape (4269, 294)
# Loaded 2018578 with shape (4916, 294)
# Loaded 2018579 with shape (4255, 294)
# Loaded 2018580 with shape (4636, 294)

# %%
import pandas as pd
import json
from pathlib import Path

# Correct relative path
meta_folder = Path("../data/dynamic_events_pl_24/meta")

# Get all JSON files
all_files = list(meta_folder.glob("*.json"))

print("Total JSON files:", len(all_files))
# Out:
# Total JSON files: 380

# %%
matches_list = []
players_list = []
periods_list = []
referees_list = []

# %%
for file in all_files:
    
    try:
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)

        match_id = data["id"]

        # -------------------
        # MATCH DATA
        # -------------------
        match_df = pd.json_normalize(
            data,
            sep="_",
            max_level=1
        )

        matches_list.append(match_df)


        # -------------------
        # PLAYERS DATA
        # -------------------
        if "players" in data:
            
            players_df = pd.json_normalize(
                data["players"],
                sep="_"
            )

            players_df["match_id"] = match_id
            players_list.append(players_df)


        # -------------------
        # PERIODS DATA
        # -------------------
        if "match_periods" in data:
            
            periods_df = pd.json_normalize(
                data["match_periods"]
            )

            periods_df["match_id"] = match_id
            periods_list.append(periods_df)


        # -------------------
        # REFEREES DATA
        # -------------------
        if "referees" in data and len(data["referees"]) > 0:
            
            refs_df = pd.json_normalize(
                data["referees"]
            )

            refs_df["match_id"] = match_id
            referees_list.append(refs_df)

    except Exception as e:
        print(f"Error reading {file.name}: {e}")

# %%
matches_df = pd.concat(matches_list, ignore_index=True)
players_df = pd.concat(players_list, ignore_index=True)
periods_df = pd.concat(periods_list, ignore_index=True)

if referees_list:
    referees_df = pd.concat(referees_list, ignore_index=True)

# %%
matches_df = matches_df.drop(
    columns=["players", "match_periods", "referees"],
    errors="ignore"
)

# %%
# SAVE FILES

from pathlib import Path

# Define the output folder
OUTPUT_PATH = Path("../data/team_build_up_analyst")
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)  # Make sure it exists

# Save DataFrames to that folder
matches_df.to_parquet(OUTPUT_PATH / "matches_clean.parquet", index=False)
players_df.to_parquet(OUTPUT_PATH / "players_match.parquet", index=False)
periods_df.to_parquet(OUTPUT_PATH / "match_periods.parquet", index=False)

print(f"Files saved in {OUTPUT_PATH.resolve()}")

#if 'referees_df' in globals():
#    referees_df.to_parquet("referees.parquet")
# Out:
# Files saved in C:\Users\vicky\Desktop\Context Engineering TWELVE - project\data\team_build_up_analyst

# %%
comp_df = pd.json_normalize(matches_df['competition_edition_competition']).add_prefix('competition_')

matches_df = pd.concat(
    [matches_df.drop(columns='competition_edition_competition'), comp_df],
    axis=1
)

# %%
# -----------------------------
# EXPAND REMAINING DICTIONARIES
# -----------------------------

# Home kit season
home_kit_season = pd.json_normalize(matches_df["home_team_kit_season"]).add_prefix("home_kit_season_")

# Away kit season
away_kit_season = pd.json_normalize(matches_df["away_team_kit_season"]).add_prefix("away_kit_season_")

# Competition season
season_df = pd.json_normalize(matches_df["competition_edition_season"]).add_prefix("season_")

# Combine everything
matches_df = pd.concat(
    [
        matches_df.drop(columns=[
            "home_team_kit_season",
            "away_team_kit_season",
            "competition_edition_season"
        ]),
        home_kit_season,
        away_kit_season,
        season_df
    ],
    axis=1
)

# -----------------------------
# CLEAN HOME TEAM SIDE
# -----------------------------

matches_df["home_team_direction_1st_half"] = matches_df["home_team_side"].str[0]
matches_df["home_team_direction_2nd_half"] = matches_df["home_team_side"].str[1]

matches_df = matches_df.drop(columns="home_team_side")

# %%
dict_cols = [col for col in matches_df.columns if matches_df[col].apply(lambda x: isinstance(x, dict)).any()]
list_cols = [col for col in matches_df.columns if matches_df[col].apply(lambda x: isinstance(x, list)).any()]

print("Dictionary columns remaining:", dict_cols)
print("List columns remaining:", list_cols)
# Out:
# Dictionary columns remaining: []
# List columns remaining: []

# %%
pd.set_option('display.max_columns', None)

matches_df.head()
# Out:
#         id  home_team_score  away_team_score             date_time  status  \
# 0  1650385                1                0  2024-08-16T19:00:00Z  closed
# 1  1650961                0                2  2024-08-17T11:30:00Z  closed
# 2  1651700                1                2  2024-08-17T16:30:00Z  closed
# 3  1651701                2                0  2024-08-17T14:00:00Z  closed
# 4  1651702                0                3  2024-08-17T14:00:00Z  closed
#
#    pitch_length  pitch_width  stadium_id                stadium_name  \
# 0           105           68          63                Old Trafford
# 1           106           66         481        Portman Road Stadium
# 2           105           68          52  Stade Olympique de Londres
# 3           105           68          69                    Emirates
# 4           101           68          89               Goodison Park
#
#   stadium_city stadium_capacity  home_team_id         home_team_name  \
# 0   Manchester            75635            31      Manchester United
# 1      Ipswich            30311           752           Ipswich Town
# 2       London            60000            37        West Ham United
# 3       London            60272             3  Arsenal Football Club
# 4    Liverpool            39571            41                Everton
#
#   home_team_short_name home_team_acronym  home_team_kit_id  \
# 0         Manchester U               MUN               549
# 1         Ipswich Town               IPS              3796
# 2             West Ham               WHU               142
# 3              Arsenal               ARS               533
# 4              Everton               EVE               253
#
#    home_team_kit_team_id home_team_kit_name home_team_kit_jersey_color  \
# 0                     31               Home                    #ff0000
# 1                    752               Home                    #0000d9
# 2                     37               home                    #882739
# 3                      3           Home alt                    #ff0000
# 4                     41               home                    #0303c8
#
#   home_team_kit_number_color  away_team_id            away_team_name  \
# 0                    #ffffff            48                    Fulham
# 1                    #ffffff             2   Liverpool Football Club
# 2                    #ffffff            39               Aston Villa
# 3                    #ffffff            52   Wolverhampton Wanderers
# 4                    #ffffff           308  Brighton and Hove Albion
#
#   away_team_short_name away_team_acronym  away_team_kit_id  \
# 0               Fulham               FUL              7510
# 1            Liverpool               LIV               250
# 2          Aston Villa               AVL              3027
# 3        Wolverhampton               WOL             10391
# 4             Brighton               BHA               175
#
#    away_team_kit_team_id away_team_kit_name away_team_kit_jersey_color  \
# 0                     48               Home                    #ffffff
# 1                      2               home                    #c10021
# 2                     39               Away                    #ffffff
# 3                     52               Away                    #fbff00
# 4                    308               away                    #fbe233
#
#   away_team_kit_number_color  home_team_coach_id home_team_coach_first_name  \
# 0                    #000000               326.0                       Ralf
# 1                    #ffffff               585.0                       Paul
# 2                    #0a163e               872.0                      David
# 3                    #000000               869.0                      Mikel
# 4                    #000000                44.0                     Rafael
#
#   home_team_coach_last_name  away_team_coach_id away_team_coach_first_name  \
# 0                  Rangnick               699.0                      Scott
# 1                   Lambert                49.0                     Jürgen
# 2                     Moyes               327.0                     Steven
# 3                    Arteta               696.0                      Bruno
# 4                   Benítez               589.0                     Graham
#
#   away_team_coach_last_name  home_team_playing_time_minutes_tip  \
# 0                    Parker                               27.94
# 1                     Klopp                               19.85
# 2                   Gerrard                               24.86
# 3                      Lage                               25.47
# 4                    Potter                               23.62
#
#    home_team_playing_time_minutes_otip  away_team_playing_time_minutes_tip  \
# 0                                25.15                               25.15
# 1                                31.06                               31.06
# 2                                28.81                               28.81
# 3                                26.23                               26.23
# 4                                30.17                               30.17
#
#    away_team_playing_time_minutes_otip  competition_edition_id  \
# 0                                27.94                     895
# 1                                19.85                     895
# 2                                24.86                     895
# 3                                25.47                     895
# 4                                23.62                     895
#
#            competition_edition_name  competition_round_id  \
# 0  ENG - Premier League - 2024/2025                     7
# 1  ENG - Premier League - 2024/2025                     7
# 2  ENG - Premier League - 2024/2025                     7
# 3  ENG - Premier League - 2024/2025                     7
# 4  ENG - Premier League - 2024/2025                     7
#
#   competition_round_name  competition_round_round_number  \
# 0                Round 1                               1
# 1                Round 1                               1
# 2                Round 1                               1
# 3                Round 1                               1
# 4                Round 1                               1
#
#    competition_round_potential_overtime  ball_trackable_object  \
# 0                                 False                     55
# 1                                 False                     55
# 2                                 False                     55
# 3                                 False                     55
# 4                                 False                     55
#
#   home_team_coach away_team_coach  competition_id competition_area  \
# 0             NaN             NaN               1              ENG
# 1             NaN             NaN               1              ENG
# 2             NaN             NaN               1              ENG
# 3             NaN             NaN               1              ENG
# 4             NaN             NaN               1              ENG
#
#   competition_name competition_gender competition_age_group  \
# 0   Premier League               male                 adult
# 1   Premier League               male                 adult
# 2   Premier League               male                 adult
# 3   Premier League               male                 adult
# 4   Premier League               male                 adult
#
#    home_kit_season_id  home_kit_season_start_year  home_kit_season_end_year  \
# 0                   5                        2018                      2019
# 1                   7                        2020                      2021
# 2                   4                        2017                      2018
# 3                   5                        2018                      2019
# 4                   4                        2017                      2018
#
#   home_kit_season_name  away_kit_season_id  away_kit_season_start_year  \
# 0            2018/2019                  20                        2022
# 1            2020/2021                   4                        2017
# 2            2017/2018                   7                        2020
# 3            2018/2019                  28                        2023
# 4            2017/2018                   4                        2017
#
#    away_kit_season_end_year away_kit_season_name  season_id  \
# 0                      2022                 2022         95
# 1                      2018            2017/2018         95
# 2                      2021            2020/2021         95
# 3                      2024            2023/2024         95
# 4                      2018            2017/2018         95
#
#    season_start_year  season_end_year season_name  \
# 0               2024             2025   2024/2025
# 1               2024             2025   2024/2025
# 2               2024             2025   2024/2025
# 3               2024             2025   2024/2025
# 4               2024             2025   2024/2025
#
#   home_team_direction_1st_half home_team_direction_2nd_half
# 0                left_to_right                right_to_left
# 1                left_to_right                right_to_left
# 2                left_to_right                right_to_left
# 3                left_to_right                right_to_left
# 4                right_to_left                left_to_right

# %%
players_list = []

for file in all_files:
    try:
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)

        match_id = data["id"]

        players = pd.json_normalize(
            data["players"],
            sep="_"
        )

        players["match_id"] = match_id

        players_list.append(players)

    except Exception as e:
        print(f"Error reading {file.name}: {e}")

players_df = pd.concat(players_list, ignore_index=True)

print(players_df.shape)
# Out:
# (15176, 30)
#   start_time  end_time  number  yellow_card  red_card  injured  goal  \
# 0   00:00:00      None      33            0         0    False     0
# 1   00:00:00  01:00:11       7            1         0    False     0
# 2   00:00:00  01:03:02      32            0         0    False     0
# 3   00:00:00  01:30:53      18            1         0    False     0
# 4   00:00:00      None       2            0         0    False     0
#
#    own_goal  team_player_id  team_id  ...  player_role_acronym  \
# 0         0           33982       48  ...                   LB
# 1         0         1062969       31  ...                   AM
# 2         0         1339102       48  ...                   CF
# 3         0          239802       48  ...                   RM
# 4         0           33697       48  ...                   RB
#
#   playing_time_total_minutes_tip playing_time_total_minutes_otip  \
# 0                          25.15                           27.94
# 1                          20.42                           14.54
# 2                          15.31                           20.45
# 3                          24.20                           26.63
# 4                          25.15                           27.94
#
#   playing_time_total_start_frame playing_time_total_end_frame  \
# 0                           10.0                      57549.0
# 1                           10.0                      36849.0
# 2                           10.0                      38559.0
# 3                           10.0                      55269.0
# 4                           10.0                      57549.0
#
#    playing_time_total_minutes_played  \
# 0                              95.88
# 1                              61.38
# 2                              64.23
# 3                              92.08
# 4                              95.88
#
#   playing_time_total_minutes_played_regular_time  \
# 0                                          95.88
# 1                                          61.38
# 2                                          64.23
# 3                                          92.08
# 4                                          95.88
#
#                               playing_time_by_period playing_time_total  \
# 0  [{'name': 'period_1', 'minutes_tip': 11.42, 'm...                NaN
# 1  [{'name': 'period_1', 'minutes_tip': 17.09, 'm...                NaN
# 2  [{'name': 'period_1', 'minutes_tip': 11.42, 'm...                NaN
# 3  [{'name': 'period_1', 'minutes_tip': 11.42, 'm...                NaN
# 4  [{'name': 'period_1', 'minutes_tip': 11.42, 'm...                NaN
#
#   match_id
# 0  1650385
# 1  1650385
# 2  1650385
# 3  1650385
# 4  1650385
#
# [5 rows x 30 columns]

# %%
# explode periods
players_periods = players_df[['team_player_id','match_id','playing_time_by_period']].explode('playing_time_by_period')

# expand dictionary
period_details = pd.json_normalize(players_periods['playing_time_by_period'])

players_periods = pd.concat(
    [players_periods.drop(columns='playing_time_by_period').reset_index(drop=True),
     period_details.reset_index(drop=True)],
    axis=1
)

# pivot to wide format
players_periods_wide = players_periods.pivot_table(
    index=['match_id','team_player_id'],
    columns='name',
    values=['minutes_tip','minutes_otip'],
    aggfunc='first'
)

# flatten column names
players_periods_wide.columns = [
    f"{period}_{metric}" for metric, period in players_periods_wide.columns
]

players_periods_wide = players_periods_wide.reset_index()

# merge back into players dataframe
players_df = players_df.merge(
    players_periods_wide,
    on=['match_id','team_player_id'],
    how='left'
)

# optional: drop original nested column
players_df = players_df.drop(columns=['playing_time_by_period'])

# %%
pd.set_option('display.max_columns', None)
players_df.head()
# Out:
#   start_time  end_time  number  yellow_card  red_card  injured  goal  \
# 0   00:00:00      None      33            0         0    False     0
# 1   00:00:00  01:00:11       7            1         0    False     0
# 2   00:00:00  01:03:02      32            0         0    False     0
# 3   00:00:00  01:30:53      18            1         0    False     0
# 4   00:00:00      None       2            0         0    False     0
#
#    own_goal  team_player_id  team_id     id first_name           last_name  \
# 0         0           33982       48  17969    Antonee            Robinson
# 1         0         1062969       31  13078      Mason               Mount
# 2         0         1339102       48  12941      Emile          Smith Rowe
# 3         0          239802       48  11438    Andreas  Hoelgebaum Pereira
# 4         0           33697       48   5794      Kenny                Tete
#
#         short_name    birthday  trackable_object gender  player_role_id  \
# 0      A. Robinson  1997-08-08             18166   male              19
# 1         M. Mount  1999-01-10             13258   male              11
# 2    E. Smith Rowe  2000-07-28             13113   male              15
# 3  Andreas Pereira  1996-01-01             11495   male              10
# 4          K. Tete  1995-10-09              5804   male              20
#
#   player_role_position_group    player_role_name player_role_acronym  \
# 0                  Full Back           Left Back                  LB
# 1                   Midfield  Attacking Midfield                  AM
# 2             Center Forward      Center Forward                  CF
# 3                   Midfield      Right Midfield                  RM
# 4                  Full Back          Right Back                  RB
#
#    playing_time_total_minutes_tip  playing_time_total_minutes_otip  \
# 0                           25.15                            27.94
# 1                           20.42                            14.54
# 2                           15.31                            20.45
# 3                           24.20                            26.63
# 4                           25.15                            27.94
#
#    playing_time_total_start_frame  playing_time_total_end_frame  \
# 0                            10.0                       57549.0
# 1                            10.0                       36849.0
# 2                            10.0                       38559.0
# 3                            10.0                       55269.0
# 4                            10.0                       57549.0
#
#    playing_time_total_minutes_played  \
# 0                              95.88
# 1                              61.38
# 2                              64.23
# 3                              92.08
# 4                              95.88
#
#    playing_time_total_minutes_played_regular_time  playing_time_total  \
# 0                                           95.88                 NaN
# 1                                           61.38                 NaN
# 2                                           64.23                 NaN
# 3                                           92.08                 NaN
# 4                                           95.88                 NaN
#
#    match_id  period_1_minutes_otip  period_2_minutes_otip  \
# 0   1650385                  17.09                  10.85
# 1   1650385                  11.42                   3.12
# 2   1650385                  17.09                   3.37
# 3   1650385                  17.09                   9.54
# 4   1650385                  17.09                  10.85
#
#    period_1_minutes_tip  period_2_minutes_tip
# 0                 11.42                 13.73
# 1                 17.09                  3.33
# 2                 11.42                  3.89
# 3                 11.42                 12.78
# 4                 11.42                 13.73

# %% [markdown]
# ## Dynamic Events

# %%
import os
import pandas as pd

# Set the correct folder path
dynamic_folder = "../data/dynamic_events_pl_24/dynamic"

# List all parquet files in the folder
parquet_files = [f for f in os.listdir(dynamic_folder) if f.endswith(".parquet")]

dynamic_dfs = {}

for file in parquet_files:
    file_path = os.path.join(dynamic_folder, file)
    match_id = file.replace(".parquet", "")
    df_name = f"match_{match_id}"  # add prefix
    
    df = pd.read_parquet(file_path)
    dynamic_dfs[df_name] = df
    
    print(f"{df_name}: {df.shape}")
# Out:
# match_1650385: (4864, 294)
# match_1650961: (4769, 294)
# match_1651700: (4181, 294)
# match_1651701: (4371, 294)
# match_1651702: (4762, 294)
# match_1651703: (4533, 294)
# match_1653146: (4441, 294)
# match_1654741: (5476, 294)
# match_1657085: (5078, 294)
# match_1666058: (5183, 294)
# match_1666917: (4656, 294)
# match_1666918: (4503, 294)
# match_1666919: (5223, 294)
# match_1666920: (5041, 294)
# match_1666921: (4948, 294)
# match_1666922: (4786, 294)
# match_1668692: (4380, 294)
# match_1669604: (5272, 294)
# match_1669605: (4437, 294)
# match_1680834: (4489, 294)
# match_1680836: (5224, 294)
# match_1680837: (4101, 294)
# match_1681563: (5509, 294)
# match_1681564: (3839, 294)
# match_1681565: (4736, 294)
# match_1681566: (3990, 294)
# match_1683027: (5050, 294)
# match_1683028: (4218, 294)
# match_1683029: (4813, 294)
# match_1711918: (4236, 294)
# match_1711920: (4438, 294)
# match_1711921: (5572, 294)
# match_1712846: (4467, 294)
# match_1712847: (4874, 294)
# match_1712849: (4400, 294)
# match_1712850: (4423, 294)
# match_1713834: (5371, 294)
# match_1715919: (4817, 294)
# match_1715920: (4329, 294)
# match_1729513: (5090, 294)
# match_1729514: (4715, 294)
# match_1729515: (4703, 294)
# match_1729516: (5108, 294)
# match_1729517: (4338, 294)
# match_1729518: (4793, 294)
# match_1729520: (4794, 294)
# match_1730528: (4457, 294)
# match_1732598: (5195, 294)
# match_1732599: (4370, 294)
# match_1747407: (4574, 294)
# match_1747409: (4933, 294)
# match_1747410: (4858, 294)
# match_1747411: (4985, 294)
# match_1747412: (4844, 294)
# match_1748494: (5214, 294)
# match_1748495: (4547, 294)
# match_1750708: (5003, 294)
# match_1751820: (5444, 294)
# match_1755069: (5138, 294)
# match_1766002: (4862, 294)
# match_1766988: (5076, 294)
# match_1766989: (5031, 294)
# match_1766990: (5665, 294)
# match_1766991: (4324, 294)
# match_1766992: (4392, 294)
# match_1766993: (4875, 294)
# match_1770288: (4573, 294)
# match_1770289: (4375, 294)
# match_1770290: (4672, 294)
# match_1799222: (4689, 294)
# match_1799223: (4540, 294)
# match_1800187: (4568, 294)
# match_1800188: (4661, 294)
# match_1800189: (4537, 294)
# match_1800190: (4696, 294)
# match_1800191: (5195, 294)
# match_1802141: (4935, 294)
# match_1803128: (4950, 294)
# match_1806021: (4738, 294)
# match_1815119: (4480, 294)
# match_1816810: (5708, 294)
# match_1816811: (4784, 294)
# match_1816812: (4632, 294)
# match_1816813: (4381, 294)
# match_1817721: (4962, 294)
# match_1819620: (4625, 294)
# match_1819621: (5048, 294)
# match_1819622: (4305, 294)
# match_1819623: (4740, 294)
# match_1832248: (4351, 294)
# match_1832948: (4390, 294)
# match_1832949: (4924, 294)
# match_1832950: (4759, 294)
# match_1832951: (4988, 294)
# match_1832952: (4002, 294)
# match_1832953: (5126, 294)
# match_1834552: (4269, 294)
# match_1835431: (4604, 294)
# match_1837900: (5135, 294)
# match_1846872: (4233, 294)
# match_1846873: (5235, 294)
# match_1846874: (4553, 294)
# match_1846875: (4742, 294)
# match_1847630: (5005, 294)
# match_1847631: (5673, 294)
# match_1849276: (4788, 294)
# match_1849277: (5177, 294)
# match_1849278: (4705, 294)
# match_1849279: (4588, 294)
# match_1873885: (4985, 294)
# match_1873886: (4781, 294)
# match_1873888: (4575, 294)
# match_1873889: (5210, 294)
# match_1873890: (4781, 294)
# match_1874584: (5484, 294)
# match_1874585: (4836, 294)
# match_1876099: (5100, 294)
# match_1876897: (5600, 294)
# match_1879054: (5388, 294)
# match_1886376: (4962, 294)
# match_1887116: (4415, 294)
# match_1887117: (4815, 294)
# match_1887118: (4278, 294)
# match_1887119: (3733, 294)
# match_1887120: (4611, 294)
# match_1888593: (4872, 294)
# match_1889313: (5121, 294)
# match_1889314: (5263, 294)
# match_1889315: (5007, 294)
# match_1893580: (5185, 294)
# match_1893581: (4917, 294)
# match_1895412: (5123, 294)
# match_1895413: (4550, 294)
# match_1895414: (4565, 294)
# match_1895415: (4405, 294)
# match_1895416: (4903, 294)
# match_1895417: (5289, 294)
# match_1897172: (4260, 294)
# match_1897173: (4811, 294)
# match_1900295: (4388, 294)
# match_1900296: (4981, 294)
# match_1900297: (4755, 294)
# match_1900298: (5550, 294)
# match_1901785: (4273, 294)
# match_1901786: (4827, 294)
# match_1902568: (4563, 294)
# match_1903346: (5042, 294)
# match_1904770: (4230, 294)
# match_1912994: (5143, 294)
# match_1912995: (5053, 294)
# match_1912996: (4807, 294)
# match_1912997: (5034, 294)
# match_1912998: (4817, 294)
# match_1915033: (5177, 294)
# match_1915034: (4898, 294)
# match_1915753: (4486, 294)
# match_1915754: (5326, 294)
# match_1917682: (4499, 294)
# match_1925317: (5230, 294)
# match_1925318: (5377, 294)
# match_1925974: (5139, 294)
# match_1925975: (4653, 294)
# match_1925976: (4239, 294)
# match_1927291: (5641, 294)
# match_1927292: (4411, 294)
# match_1927293: (5058, 294)
# match_1927294: (4687, 294)
# match_1927295: (4602, 294)
# match_1934145: (4750, 294)
# match_1934146: (5633, 294)
# match_1934147: (4955, 294)
# match_1934150: (5338, 294)
# match_1934786: (4972, 294)
# match_1934787: (5162, 294)
# match_1934788: (4627, 294)
# match_1934789: (4724, 294)
# match_1936645: (5633, 294)
# match_1936646: (4669, 294)
# match_1939711: (5375, 294)
# match_1939712: (4550, 294)
# match_1939713: (4055, 294)
# match_1939714: (5086, 294)
# match_1939715: (4414, 294)
# match_1939716: (5704, 294)
# match_1941550: (5822, 294)
# match_1941551: (4480, 294)
# match_1941552: (4997, 294)
# match_1945190: (5323, 294)
# match_1949357: (5363, 294)
# match_1949358: (5278, 294)
# match_1949360: (4836, 294)
# match_1949361: (5371, 294)
# match_1949362: (4974, 294)
# match_1949363: (4722, 294)
# match_1951174: (4285, 294)
# match_1951175: (4867, 294)
# match_1951807: (3801, 294)
# match_1953619: (4902, 294)
# match_1966655: (4340, 294)
# match_1967223: (5187, 294)
# match_1967224: (4927, 294)
# match_1967225: (4027, 294)
# match_1968372: (4640, 294)
# match_1968373: (4605, 294)
# match_1968374: (5437, 294)
# match_1968375: (5371, 294)
# match_1969492: (5209, 294)
# match_1970055: (4718, 294)
# match_1972418: (4256, 294)
# match_1972419: (4593, 294)
# match_1972420: (5026, 294)
# match_1972421: (5350, 294)
# match_1972422: (4211, 294)
# match_1974368: (5845, 294)
# match_1974369: (4863, 294)
# match_1974370: (4628, 294)
# match_1974371: (4735, 294)
# match_1976820: (4912, 294)
# match_1985287: (5157, 294)
# match_1985288: (3981, 294)
# match_1985289: (4779, 294)
# match_1985290: (5504, 294)
# match_1985291: (4875, 294)
# match_1985292: (4958, 294)
# match_1986707: (4746, 294)
# match_1986708: (3765, 294)
# match_1986709: (4696, 294)
# match_1987415: (5295, 294)
# match_1997065: (4875, 294)
# match_1997066: (4997, 294)
# match_1997067: (4610, 294)
# match_1997068: (4776, 294)
# match_1997729: (4495, 294)
# match_1999189: (4896, 294)
# match_1999190: (4895, 294)
# match_1999191: (4695, 294)
# match_1999980: (4535, 294)
# match_2001338: (4635, 294)
# match_2003007: (4366, 294)
# match_2003157: (5469, 294)
# match_2003245: (4440, 294)
# match_2003325: (4608, 294)
# match_2003326: (5064, 294)
# match_2003327: (4928, 294)
# match_2003328: (5221, 294)
# match_2003329: (4718, 294)
# match_2003330: (4644, 294)
# match_2003492: (5147, 294)
# match_2003493: (4829, 294)
# match_2003931: (4673, 294)
# match_2004054: (4643, 294)
# match_2004167: (4970, 294)
# match_2004168: (5244, 294)
# match_2004170: (4698, 294)
# match_2004171: (4689, 294)
# match_2004172: (4514, 294)
# match_2004173: (4626, 294)
# match_2004437: (5476, 294)
# match_2004438: (4498, 294)
# match_2004875: (5422, 294)
# match_2004876: (4562, 294)
# match_2004877: (5158, 294)
# match_2004878: (4055, 294)
# match_2004973: (4842, 294)
# match_2004974: (4653, 294)
# match_2005040: (5121, 294)
# match_2005041: (4535, 294)
# match_2005042: (5174, 294)
# match_2005099: (5798, 294)
# match_2006304: (4770, 294)
# match_2006396: (4855, 294)
# match_2006397: (4387, 294)
# match_2006398: (5164, 294)
# match_2006399: (4077, 294)
# match_2006400: (4926, 294)
# match_2006584: (4977, 294)
# match_2006585: (5067, 294)
# match_2006586: (4812, 294)
# match_2006857: (4804, 294)
# match_2007481: (4893, 294)
# match_2007482: (4252, 294)
# match_2007483: (4468, 294)
# match_2007484: (5310, 294)
# match_2007558: (4388, 294)
# match_2007736: (4713, 294)
# match_2007737: (5294, 294)
# match_2007863: (5130, 294)
# match_2009693: (5166, 294)
# match_2009694: (5156, 294)
# match_2009695: (5146, 294)
# match_2009783: (4486, 294)
# match_2009784: (4618, 294)
# match_2009785: (5535, 294)
# match_2009786: (4447, 294)
# match_2009787: (4774, 294)
# match_2009828: (4499, 294)
# match_2009901: (4695, 294)
# match_2010150: (4542, 294)
# match_2010151: (4536, 294)
# match_2010152: (3921, 294)
# match_2010153: (4266, 294)
# match_2010154: (3590, 294)
# match_2010323: (4398, 294)
# match_2010324: (5110, 294)
# match_2010325: (5087, 294)
# match_2010414: (5122, 294)
# match_2010636: (5032, 294)
# match_2011150: (5587, 294)
# match_2011202: (4292, 294)
# match_2011203: (4378, 294)
# match_2011204: (3982, 294)
# match_2011205: (4791, 294)
# match_2011367: (4227, 294)
# match_2011368: (4860, 294)
# match_2011442: (4799, 294)
# match_2011443: (4986, 294)
# match_2011600: (4415, 294)
# match_2011870: (4541, 294)
# match_2012175: (5049, 294)
# match_2012176: (4402, 294)
# match_2012177: (4726, 294)
# match_2012232: (4604, 294)
# match_2012233: (5284, 294)
# match_2012369: (4746, 294)
# match_2012370: (4962, 294)
# match_2012371: (5532, 294)
# match_2012372: (5206, 294)
# match_2012598: (4201, 294)
# match_2012757: (4270, 294)
# match_2012907: (5512, 294)
# match_2013340: (5232, 294)
# match_2013341: (4392, 294)
# match_2013342: (4664, 294)
# match_2013343: (5555, 294)
# match_2013344: (4646, 294)
# match_2013551: (4358, 294)
# match_2013552: (4152, 294)
# match_2014169: (3792, 294)
# match_2014723: (5681, 294)
# match_2014780: (4824, 294)
# match_2014830: (4750, 294)
# match_2014831: (4591, 294)
# match_2014832: (4660, 294)
# match_2014999: (4908, 294)
# match_2015000: (4397, 294)
# match_2015001: (3976, 294)
# match_2015068: (5051, 294)
# match_2015490: (4388, 294)
# match_2016341: (3961, 294)
# match_2016342: (4619, 294)
# match_2016343: (4094, 294)
# match_2016344: (4879, 294)
# match_2016345: (5218, 294)
# match_2016514: (5257, 294)
# match_2016515: (3952, 294)
# match_2016516: (4663, 294)
# match_2016626: (4563, 294)
# match_2016627: (4121, 294)
# match_2017367: (4384, 294)
# match_2017368: (4603, 294)
# match_2017616: (4991, 294)
# match_2017698: (4575, 294)
# match_2017699: (4054, 294)
# match_2017700: (4609, 294)
# match_2017701: (4676, 294)
# match_2017924: (5140, 294)
# match_2018120: (4636, 294)
# match_2018121: (5604, 294)
# match_2018571: (3919, 294)
# match_2018572: (5161, 294)
# match_2018573: (5576, 294)
# match_2018574: (5104, 294)
# match_2018575: (4957, 294)
# match_2018576: (4526, 294)
# match_2018577: (4269, 294)
# match_2018578: (4916, 294)
# match_2018579: (4255, 294)
# match_2018580: (4636, 294)

# %%
# Search for a match to look at

match_filter = matches_expanded[
    ((matches_expanded['home_short_name'] == "Manchester City") & (matches_expanded['away_short_name'] == "Brighton")) |
    ((matches_expanded['home_short_name'] == "Brighton") & (matches_expanded['away_short_name'] == "Manchester City"))
]

match_filter
# Out:
#           id             date_time  status  competition_id  season_id  \
# 97   2007483  2025-03-15T15:00:00Z  closed               1         95
# 275  1847631  2024-11-09T17:30:00Z  closed               1         95
#
#      competition_edition_id  home_id  home_short_name  away_id  \
# 97                      895       40  Manchester City      308
# 275                     895      308         Brighton       40
#
#      away_short_name
# 97          Brighton
# 275  Manchester City

# %%
dynamic_dfs["match_1847631"] # Bournemouth - Leicester
# Out:
#      event_id  index  match_id  frame_start  frame_end  frame_physical_start  \
# 0         8_0      0   1847631           32         32                   NaN
# 1         8_1      1   1847631           59         83                   NaN
# 2         7_0      2   1847631           59         83                   NaN
# 3         7_1      3   1847631           67         83                   NaN
# 4         7_2      4   1847631           73         83                   NaN
# ...       ...    ...       ...          ...        ...                   ...
# 5668   8_1122   5668   1847631        60793      60793                   NaN
# 5669   8_1123   5669   1847631        60796      60796                   NaN
# 5670   8_1124   5670   1847631        61470      61470                   NaN
# 5671   7_3071   5671   1847631        61470      61470                   NaN
# 5672   7_3072   5672   1847631        61470      61470                   NaN
#
#      time_start time_end  minute_start  second_start  duration  period  \
# 0       00:02.2  00:02.2             0             2       0.0       1
# 1       00:04.9  00:07.3             0             4       2.4       1
# 2       00:04.9  00:07.3             0             4       2.4       1
# 3       00:05.7  00:07.3             0             5       1.6       1
# 4       00:06.3  00:07.3             0             6       1.0       1
# ...         ...      ...           ...           ...       ...     ...
# 5668    98:41.3  98:41.3            98            41       0.0       2
# 5669    98:41.6  98:41.6            98            41       0.0       2
# 5670    99:49.0  99:49.0            99            49       0.0       2
# 5671    99:49.0  99:49.0            99            49       0.0       2
# 5672    99:49.0  99:49.0            99            49       0.0       2
#
#       attacking_side_id attacking_side  event_type_id         event_type  \
# 0                     2  right_to_left              8  player_possession
# 1                     2  right_to_left              8  player_possession
# 2                     2  right_to_left              7     passing_option
# 3                     2  right_to_left              7     passing_option
# 4                     2  right_to_left              7     passing_option
# ...                 ...            ...            ...                ...
# 5668                  2  right_to_left              8  player_possession
# 5669                  1  left_to_right              8  player_possession
# 5670                  2  right_to_left              8  player_possession
# 5671                  2  right_to_left              7     passing_option
# 5672                  2  right_to_left              7     passing_option
#
#       event_subtype_id event_subtype  player_id     player_name  \
# 0                  NaN          None       4450     İ. Gündoğan
# 1                  NaN          None       2924         Ederson
# 2                  NaN          None      16407      E. Haaland
# 3                  NaN          None      11591        P. Foden
# 4                  NaN          None      32839         Savinho
# ...                ...           ...        ...             ...
# 5668               NaN          None       5130      J. Veltman
# 5669               NaN          None       1326  Bernardo Silva
# 5670               NaN          None       2325      D. Welbeck
# 5671               NaN          None      24703      João Pedro
# 5672               NaN          None     206700        B. Gruda
#
#       player_position_id player_position  player_in_possession_id  \
# 0                     12              LM                      NaN
# 1                      1              GK                      NaN
# 2                     19              CF                   2924.0
# 3                     14              RM                   2924.0
# 4                     17              RW                   2924.0
# ...                  ...             ...                      ...
# 5668                   8              RB                      NaN
# 5669                  12              LM                      NaN
# 5670                  19              CF                      NaN
# 5671                  19              CF                   2325.0
# 5672                  17              RW                   2325.0
#
#      player_in_possession_name  player_in_possession_position_id  \
# 0                         None                               NaN
# 1                         None                               NaN
# 2                      Ederson                               1.0
# 3                      Ederson                               1.0
# 4                      Ederson                               1.0
# ...                        ...                               ...
# 5668                      None                               NaN
# 5669                      None                               NaN
# 5670                      None                               NaN
# 5671                D. Welbeck                              19.0
# 5672                D. Welbeck                              19.0
#
#      player_in_possession_position  team_id   team_shortname  x_start  \
# 0                             None       40  Manchester City     0.45
# 1                             None       40  Manchester City   -34.83
# 2                               GK       40  Manchester City    10.88
# 3                               GK       40  Manchester City     8.80
# 4                               GK       40  Manchester City    16.03
# ...                            ...      ...              ...      ...
# 5668                          None      308         Brighton   -48.17
# 5669                          None       40  Manchester City    43.97
# 5670                          None      308         Brighton    11.04
# 5671                            CF      308         Brighton     8.50
# 5672                            CF      308         Brighton     8.70
#
#       y_start  channel_id_start     channel_start  third_id_start  \
# 0       -0.70                 3            center               2
# 1       -0.99                 3            center               1
# 2      -23.00                 5        wide_right               2
# 3      -17.08                 4  half_space_right               2
# 4      -29.96                 5        wide_right               2
# ...       ...               ...               ...             ...
# 5668    -0.05                 3            center               1
# 5669    -7.90                 3            center               3
# 5670   -19.26                 4  half_space_right               2
# 5671   -16.68                 4  half_space_right               2
# 5672   -27.38                 5        wide_right               2
#
#           third_start  penalty_area_start  x_end  y_end  channel_id_end  \
# 0        middle_third               False   0.45  -0.70               3
# 1     defensive_third               False -29.72   0.03               3
# 2        middle_third               False  18.32 -20.96               5
# 3        middle_third               False  12.85 -17.63               4
# 4        middle_third               False  18.21 -29.60               5
# ...               ...                 ...    ...    ...             ...
# 5668  defensive_third               False -48.17  -0.05               3
# 5669  attacking_third                True  43.97  -7.90               3
# 5670     middle_third               False  11.04 -19.26               4
# 5671     middle_third               False   8.50 -16.68               4
# 5672     middle_third               False   8.70 -27.38               5
#
#            channel_end  third_id_end        third_end  penalty_area_end  \
# 0               center             2     middle_third             False
# 1               center             1  defensive_third             False
# 2           wide_right             3  attacking_third             False
# 3     half_space_right             2     middle_third             False
# 4           wide_right             3  attacking_third             False
# ...                ...           ...              ...               ...
# 5668            center             1  defensive_third             False
# 5669            center             3  attacking_third              True
# 5670  half_space_right             2     middle_third             False
# 5671  half_space_right             2     middle_third             False
# 5672        wide_right             2     middle_third             False
#
#      associated_player_possession_event_id  \
# 0                                     None
# 1                                     None
# 2                                      8_1
# 3                                      8_1
# 4                                      8_1
# ...                                    ...
# 5668                                  None
# 5669                                  None
# 5670                                  None
# 5671                                8_1124
# 5672                                8_1124
#
#       associated_player_possession_frame_start  \
# 0                                          NaN
# 1                                          NaN
# 2                                         59.0
# 3                                         59.0
# 4                                         59.0
# ...                                        ...
# 5668                                       NaN
# 5669                                       NaN
# 5670                                       NaN
# 5671                                   61470.0
# 5672                                   61470.0
#
#       associated_player_possession_frame_end  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5668                                     NaN
# 5669                                     NaN
# 5670                                     NaN
# 5671                                     NaN
# 5672                                     NaN
#
#       associated_player_possession_end_type_id  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5668                                       NaN
# 5669                                       NaN
# 5670                                       NaN
# 5671                                       NaN
# 5672                                       NaN
#
#      associated_player_possession_end_type associated_off_ball_run_event_id  \
# 0                                     None                             None
# 1                                     None                             None
# 2                                     None                             None
# 3                                     None                             None
# 4                                     None                             None
# ...                                    ...                              ...
# 5668                                  None                             None
# 5669                                  None                             None
# 5670                                  None                             None
# 5671                                  None                             None
# 5672                                  None                             None
#
#       associated_off_ball_run_subtype_id associated_off_ball_run_subtype  \
# 0                                    NaN                            None
# 1                                    NaN                            None
# 2                                    NaN                            None
# 3                                    NaN                            None
# 4                                    NaN                            None
# ...                                  ...                             ...
# 5668                                 NaN                            None
# 5669                                 NaN                            None
# 5670                                 NaN                            None
# 5671                                 NaN                            None
# 5672                                 NaN                            None
#
#       game_state_id game_state  team_score  opponent_team_score  phase_index  \
# 0                 3    drawing           0                    0            0
# 1                 3    drawing           0                    0            2
# 2                 3    drawing           0                    0            2
# 3                 3    drawing           0                    0            2
# 4                 3    drawing           0                    0            2
# ...             ...        ...         ...                  ...          ...
# 5668              1    winning           2                    1          361
# 5669              2     losing           1                    2          362
# 5670              1    winning           2                    1          363
# 5671              1    winning           2                    1          363
# 5672              1    winning           2                    1          363
#
#       player_possession_phase_index  \
# 0                               1.0
# 1                               1.0
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 5668                            2.0
# 5669                            1.0
# 5670                            1.0
# 5671                            NaN
# 5672                            NaN
#
#      first_player_possession_in_team_possession  \
# 0                                          True
# 1                                         False
# 2                                          None
# 3                                          None
# 4                                          None
# ...                                         ...
# 5668                                       True
# 5669                                       True
# 5670                                       True
# 5671                                       None
# 5672                                       None
#
#      last_player_possession_in_team_possession lead_to_different_phase  \
# 0                                        False                    True
# 1                                        False                   False
# 2                                         None                    None
# 3                                         None                    None
# 4                                         None                    None
# ...                                        ...                     ...
# 5668                                      True                    True
# 5669                                      True                    True
# 5670                                      True                    True
# 5671                                      None                    None
# 5672                                      None                    None
#
#      issued_from_different_phase  n_player_possessions_in_phase  \
# 0                           True                            1.0
# 1                           True                            2.0
# 2                           None                            NaN
# 3                           None                            NaN
# 4                           None                            NaN
# ...                          ...                            ...
# 5668                        True                            1.0
# 5669                        True                            1.0
# 5670                        True                            1.0
# 5671                        None                            NaN
# 5672                        None                            NaN
#
#      team_possession_loss_in_phase  team_in_possession_phase_type_id  \
# 0                            False                                 1
# 1                             True                                 6
# 2                             None                                 6
# 3                             None                                 6
# 4                             None                                 6
# ...                            ...                               ...
# 5668                          True                                 5
# 5669                          True                                 2
# 5670                         False                                 6
# 5671                          None                                 6
# 5672                          None                                 6
#
#      team_in_possession_phase_type  team_out_of_possession_phase_type_id  \
# 0                           create                                     9
# 1                           direct                                    15
# 2                           direct                                    15
# 3                           direct                                    15
# 4                           direct                                    15
# ...                            ...                                   ...
# 5668                       chaotic                                     5
# 5669                        finish                                     8
# 5670                        direct                                    15
# 5671                        direct                                    15
# 5672                        direct                                    15
#
#      team_out_of_possession_phase_type  \
# 0                         medium_block
# 1                     defending_direct
# 2                     defending_direct
# 3                     defending_direct
# 4                     defending_direct
# ...                                ...
# 5668                           chaotic
# 5669                         low_block
# 5670                  defending_direct
# 5671                  defending_direct
# 5672                  defending_direct
#
#       current_team_in_possession_next_phase_type_id  \
# 0                                               0.0
# 1                                               5.0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5668                                            8.0
# 5669                                           15.0
# 5670                                            NaN
# 5671                                            NaN
# 5672                                            NaN
#
#      current_team_in_possession_next_phase_type  \
# 0                                      build_up
# 1                                       chaotic
# 2                                          None
# 3                                          None
# 4                                          None
# ...                                         ...
# 5668                                  low_block
# 5669                           defending_direct
# 5670                                       None
# 5671                                       None
# 5672                                       None
#
#       current_team_out_of_possession_next_phase_type_id  \
# 0                                                  10.0
# 1                                                   5.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5668                                                2.0
# 5669                                                6.0
# 5670                                                NaN
# 5671                                                NaN
# 5672                                                NaN
#
#      current_team_out_of_possession_next_phase_type  \
# 0                                        high_block
# 1                                           chaotic
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 5668                                         finish
# 5669                                         direct
# 5670                                           None
# 5671                                           None
# 5672                                           None
#
#       current_team_in_possession_previous_phase_type_id  \
# 0                                                   NaN
# 1                                                   0.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5668                                                5.0
# 5669                                                5.0
# 5670                                                8.0
# 5671                                                NaN
# 5672                                                NaN
#
#      current_team_in_possession_previous_phase_type  \
# 0                                              None
# 1                                          build_up
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 5668                                        chaotic
# 5669                                        chaotic
# 5670                                      low_block
# 5671                                           None
# 5672                                           None
#
#       current_team_out_of_possession_previous_phase_type_id  \
# 0                                                   NaN
# 1                                                  10.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5668                                                5.0
# 5669                                                5.0
# 5670                                                2.0
# 5671                                                NaN
# 5672                                                NaN
#
#      current_team_out_of_possession_previous_phase_type  \
# 0                                                  None
# 1                                            high_block
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 5668                                            chaotic
# 5669                                            chaotic
# 5670                                             finish
# 5671                                               None
# 5672                                               None
#
#       game_interruption_before_id game_interruption_before  \
# 0                             NaN                     None
# 1                             NaN                     None
# 2                             NaN                     None
# 3                             NaN                     None
# 4                             NaN                     None
# ...                           ...                      ...
# 5668                          NaN                     None
# 5669                          NaN                     None
# 5670                          3.0            free_kick_for
# 5671                          NaN                     None
# 5672                          NaN                     None
#
#       game_interruption_after_id game_interruption_after  lead_to_shot  \
# 0                            NaN                    None         False
# 1                            NaN                    None         False
# 2                            NaN                    None         False
# 3                            NaN                    None         False
# 4                            NaN                    None         False
# ...                          ...                     ...           ...
# 5668                         NaN                    None         False
# 5669                         4.0       free_kick_against          True
# 5670                         NaN                    None         False
# 5671                         NaN                    None         False
# 5672                         NaN                    None         False
#
#       lead_to_goal  distance_covered  trajectory_angle  \
# 0            False              0.00            145.01
# 1            False              5.40             11.29
# 2            False              7.75             15.33
# 3            False              4.09             -7.73
# 4            False              2.21              9.38
# ...            ...               ...               ...
# 5668         False              0.00             96.15
# 5669         False              0.00            -28.61
# 5670         False              0.00             77.77
# 5671         False              0.00              4.51
# 5672         False              0.00             67.17
#
#       trajectory_direction_id trajectory_direction in_to_out out_to_in  \
# 0                         2.0             backward      None      None
# 1                         1.0              forward     False     False
# 2                         1.0              forward     False     False
# 3                         1.0              forward     False     False
# 4                         1.0              forward     False     False
# ...                       ...                  ...       ...       ...
# 5668                      3.0         sideway_left      None      None
# 5669                      1.0              forward      None      None
# 5670                      3.0         sideway_left      None      None
# 5671                      1.0              forward     False     False
# 5672                      3.0         sideway_left     False     False
#
#       speed_avg  speed_avg_band_id speed_avg_band  separation_start  \
# 0          3.47                1.0        jogging              8.25
# 1          8.05                1.0        jogging             26.48
# 2           NaN                NaN           None              2.54
# 3           NaN                NaN           None              5.18
# 4           NaN                NaN           None             10.52
# ...         ...                ...            ...               ...
# 5668       9.52                1.0        jogging              2.31
# 5669       5.62                1.0        jogging              2.30
# 5670       8.83                1.0        jogging              1.23
# 5671       5.40                1.0        jogging              3.37
# 5672       4.48                1.0        jogging              6.45
#
#       separation_end  separation_gain  last_defensive_line_x_start  \
# 0               8.25             0.00                        20.72
# 1               8.85           -17.63                        19.62
# 2               0.50            -2.04                        19.62
# 3               3.56            -1.62                        19.34
# 4              11.21             0.69                        19.74
# ...              ...              ...                          ...
# 5668            2.31             0.00                       -22.78
# 5669            2.30             0.00                        48.00
# 5670            1.23             0.00                        14.35
# 5671            3.37             0.00                        14.35
# 5672            2.82            -3.63                        14.35
#
#       last_defensive_line_x_end  delta_to_last_defensive_line_start  \
# 0                         20.72                               20.27
# 1                         20.95                               54.45
# 2                         20.95                                8.74
# 3                         20.95                               10.54
# 4                         20.95                                3.71
# ...                         ...                                 ...
# 5668                     -22.78                               25.39
# 5669                      48.00                                4.03
# 5670                      14.35                                3.31
# 5671                      14.35                                5.85
# 5672                      14.35                                5.65
#
#       delta_to_last_defensive_line_end  delta_to_last_defensive_line_gain  \
# 0                                20.27                               0.00
# 1                                50.67                              -3.78
# 2                                 2.63                              -6.11
# 3                                 8.10                              -2.44
# 4                                 2.74                              -0.97
# ...                                ...                                ...
# 5668                             25.39                               0.00
# 5669                              4.03                               0.00
# 5670                              3.31                               0.00
# 5671                              5.85                               0.00
# 5672                              5.65                               0.00
#
#       last_defensive_line_height_start  last_defensive_line_height_end  \
# 0                                31.78                           31.78
# 1                                32.88                           31.55
# 2                                32.88                           31.55
# 3                                33.16                           31.55
# 4                                32.76                           31.55
# ...                                ...                             ...
# 5668                             75.28                           75.28
# 5669                              4.50                            4.50
# 5670                             38.15                           38.15
# 5671                             38.15                           38.15
# 5672                             38.15                           38.15
#
#       last_defensive_line_height_gain inside_defensive_shape_start  \
# 0                                0.00                         True
# 1                               -1.33                        False
# 2                               -1.33                        False
# 3                               -1.61                         True
# 4                               -1.21                        False
# ...                               ...                          ...
# 5668                             0.00                         True
# 5669                             0.00                         True
# 5670                             0.00                         True
# 5671                             0.00                         True
# 5672                             0.00                        False
#
#      inside_defensive_shape_end  start_type_id           start_type  \
# 0                          True           13.0              unknown
# 1                         False            1.0       pass_reception
# 2                         False            NaN                 None
# 3                          True            NaN                 None
# 4                         False            NaN                 None
# ...                         ...            ...                  ...
# 5668                       True            2.0    pass_interception
# 5669                       True            2.0    pass_interception
# 5670                       True            5.0  free_kick_reception
# 5671                       True            NaN                 None
# 5672                      False            NaN                 None
#
#       end_type_id end_type consecutive_on_ball_engagements one_touch  \
# 0             1.0     pass                            None      True
# 1             1.0     pass                            None     False
# 2             NaN     None                            None      None
# 3             NaN     None                            None      None
# 4             NaN     None                            None      None
# ...           ...      ...                             ...       ...
# 5668          1.0     pass                            None      True
# 5669          2.0     shot                            None      True
# 5670          1.0     pass                            None      True
# 5671          NaN     None                            None      None
# 5672          NaN     None                            None      None
#
#      quick_pass  carry forward_momentum is_header hand_pass  \
# 0         False  False            False     False     False
# 1         False   True            False     False     False
# 2          None   None             None      None      None
# 3          None   None             None      None      None
# 4          None   None             None      None      None
# ...         ...    ...              ...       ...       ...
# 5668      False  False            False      True     False
# 5669      False  False            False      True     False
# 5670      False  False            False      True     False
# 5671       None   None             None      None      None
# 5672       None   None             None      None      None
#
#      initiate_give_and_go  pass_angle_received  pass_direction_received_id  \
# 0                   False                  NaN                         NaN
# 1                   False              -177.79                         2.0
# 2                    None                  NaN                         NaN
# 3                    None                  NaN                         NaN
# 4                    None                  NaN                         NaN
# ...                   ...                  ...                         ...
# 5668                False                  NaN                         NaN
# 5669                False                  NaN                         NaN
# 5670                False                  NaN                         NaN
# 5671                 None                  NaN                         NaN
# 5672                 None                  NaN                         NaN
#
#      pass_direction_received  pass_distance_received  pass_range_received_id  \
# 0                       None                     NaN                     NaN
# 1                   backward                   43.07                     3.0
# 2                       None                     NaN                     NaN
# 3                       None                     NaN                     NaN
# 4                       None                     NaN                     NaN
# ...                      ...                     ...                     ...
# 5668                    None                     NaN                     NaN
# 5669                    None                     NaN                     NaN
# 5670                    None                     NaN                     NaN
# 5671                    None                     NaN                     NaN
# 5672                    None                     NaN                     NaN
#
#      pass_range_received  pass_outcome_id  pass_outcome  \
# 0                   None              1.0    successful
# 1                   long              1.0    successful
# 2                   None              NaN          None
# 3                   None              NaN          None
# 4                   None              NaN          None
# ...                  ...              ...           ...
# 5668                None              2.0  unsuccessful
# 5669                None              NaN          None
# 5670                None              1.0    successful
# 5671                None              NaN          None
# 5672                None              NaN          None
#
#      targeted_passing_option_event_id high_pass  player_targeted_id  \
# 0                                None      None              2924.0
# 1                                 7_0      True             16407.0
# 2                                None      True                 NaN
# 3                                None      None                 NaN
# 4                                None      None                 NaN
# ...                               ...       ...                 ...
# 5668                             None      None             32768.0
# 5669                             None      None                 NaN
# 5670                           7_3072      None            206700.0
# 5671                             None      None                 NaN
# 5672                             None      None                 NaN
#
#      player_targeted_name  player_targeted_position_id  \
# 0                 Ederson                          1.0
# 1              E. Haaland                         19.0
# 2                    None                          NaN
# 3                    None                          NaN
# 4                    None                          NaN
# ...                   ...                          ...
# 5668        B. Verbruggen                          1.0
# 5669                 None                          NaN
# 5670             B. Gruda                         17.0
# 5671                 None                          NaN
# 5672                 None                          NaN
#
#      player_targeted_position  player_targeted_x_pass  player_targeted_y_pass  \
# 0                          GK                  -38.21                   -0.34
# 1                          CF                   18.32                  -20.96
# 2                        None                     NaN                     NaN
# 3                        None                     NaN                     NaN
# 4                        None                     NaN                     NaN
# ...                       ...                     ...                     ...
# 5668                       GK                  -51.55                    1.52
# 5669                     None                     NaN                     NaN
# 5670                       RW                    8.70                  -27.38
# 5671                     None                     NaN                     NaN
# 5672                     None                     NaN                     NaN
#
#       player_targeted_channel_pass_id player_targeted_channel_pass  \
# 0                                 3.0                       center
# 1                                 5.0                   wide_right
# 2                                 NaN                         None
# 3                                 NaN                         None
# 4                                 NaN                         None
# ...                               ...                          ...
# 5668                              3.0                       center
# 5669                              NaN                         None
# 5670                              5.0                   wide_right
# 5671                              NaN                         None
# 5672                              NaN                         None
#
#       player_targeted_third_pass_id player_targeted_third_pass  \
# 0                               1.0            defensive_third
# 1                               3.0            attacking_third
# 2                               NaN                       None
# 3                               NaN                       None
# 4                               NaN                       None
# ...                             ...                        ...
# 5668                            1.0            defensive_third
# 5669                            NaN                       None
# 5670                            2.0               middle_third
# 5671                            NaN                       None
# 5672                            NaN                       None
#
#      player_targeted_penalty_area_pass  player_targeted_x_reception  \
# 0                                False                       -34.83
# 1                                False                        29.50
# 2                                 None                          NaN
# 3                                 None                          NaN
# 4                                 None                          NaN
# ...                                ...                          ...
# 5668                             False                          NaN
# 5669                              None                          NaN
# 5670                             False                         7.63
# 5671                              None                          NaN
# 5672                              None                          NaN
#
#       player_targeted_y_reception  player_targeted_channel_reception_id  \
# 0                           -0.99                                   3.0
# 1                          -23.39                                   5.0
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 5668                          NaN                                   NaN
# 5669                          NaN                                   NaN
# 5670                       -25.60                                   5.0
# 5671                          NaN                                   NaN
# 5672                          NaN                                   NaN
#
#      player_targeted_channel_reception  player_targeted_third_reception_id  \
# 0                               center                                 1.0
# 1                           wide_right                                 3.0
# 2                                 None                                 NaN
# 3                                 None                                 NaN
# 4                                 None                                 NaN
# ...                                ...                                 ...
# 5668                              None                                 NaN
# 5669                              None                                 NaN
# 5670                        wide_right                                 2.0
# 5671                              None                                 NaN
# 5672                              None                                 NaN
#
#      player_targeted_third_reception player_targeted_penalty_area_reception  \
# 0                    defensive_third                                  False
# 1                    attacking_third                                  False
# 2                               None                                   None
# 3                               None                                   None
# 4                               None                                   None
# ...                              ...                                    ...
# 5668                            None                                   None
# 5669                            None                                   None
# 5670                    middle_third                                  False
# 5671                            None                                   None
# 5672                            None                                   None
#
#       player_targeted_distance_to_goal_start  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5668                                     NaN
# 5669                                     NaN
# 5670                                     NaN
# 5671                                     NaN
# 5672                                     NaN
#
#       player_targeted_distance_to_goal_end  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5668                                   NaN
# 5669                                   NaN
# 5670                                   NaN
# 5671                                   NaN
# 5672                                   NaN
#
#       player_targeted_angle_to_goal_start  player_targeted_angle_to_goal_end  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 5668                                  NaN                                NaN
# 5669                                  NaN                                NaN
# 5670                                  NaN                                NaN
# 5671                                  NaN                                NaN
# 5672                                  NaN                                NaN
#
#       player_targeted_average_speed  player_targeted_speed_avg_band_id  \
# 0                               NaN                                NaN
# ...
# 3                    None                    None
# 4                    None                    None
# ...                   ...                     ...
# 5668                 None                    None
# 5669                 None                    None
# 5670                 None                    None
# 5671                 None                    None
# 5672                 None                    None
#
#       n_simultaneous_passing_options passing_option_at_pass_moment  \
# 0                                NaN                          None
# 1                                NaN                          None
# 2                                3.0                          True
# 3                                3.0                          True
# 4                                3.0                          True
# ...                              ...                           ...
# 5668                             NaN                          None
# 5669                             NaN                          None
# 5670                             NaN                          None
# 5671                             1.0                          True
# 5672                             1.0                          True
#
#       n_opponents_ahead_end  n_opponents_ahead_start  n_opponents_overtaken  \
# 0                       8.0                      8.0                    0.0
# 1                      10.0                     10.0                    0.0
# 2                       NaN                      NaN                    NaN
# 3                       NaN                      NaN                    NaN
# 4                       NaN                      NaN                    NaN
# ...                     ...                      ...                    ...
# 5668                    7.0                      7.0                    0.0
# 5669                    5.0                      5.0                    0.0
# 5670                    3.0                      3.0                    0.0
# 5671                    NaN                      NaN                    NaN
# 5672                    NaN                      NaN                    NaN
#
#      pressing_chain  pressing_chain_length  pressing_chain_end_type_id  \
# 0              None                    NaN                         NaN
# 1              None                    NaN                         NaN
# 2              None                    NaN                         NaN
# 3              None                    NaN                         NaN
# 4              None                    NaN                         NaN
# ...             ...                    ...                         ...
# 5668           None                    NaN                         NaN
# 5669           None                    NaN                         NaN
# 5670           None                    NaN                         NaN
# 5671           None                    NaN                         NaN
# 5672           None                    NaN                         NaN
#
#      pressing_chain_end_type  pressing_chain_index  index_in_pressing_chain  \
# 0                       None                   NaN                      NaN
# 1                       None                   NaN                      NaN
# 2                       None                   NaN                      NaN
# 3                       None                   NaN                      NaN
# 4                       None                   NaN                      NaN
# ...                      ...                   ...                      ...
# 5668                    None                   NaN                      NaN
# 5669                    None                   NaN                      NaN
# 5670                    None                   NaN                      NaN
# 5671                    None                   NaN                      NaN
# 5672                    None                   NaN                      NaN
#
#      simultaneous_defensive_engagement_same_target  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# ...                                            ...
# 5668                                          None
# 5669                                          None
# 5670                                          None
# 5671                                          None
# 5672                                          None
#
#       simultaneous_defensive_engagement_same_target_rank  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5668                                                NaN
# 5669                                                NaN
# 5670                                                NaN
# 5671                                                NaN
# 5672                                                NaN
#
#      affected_line_breaking_passing_option_id  affected_line_break_id  \
# 0                                        None                     NaN
# 1                                        None                     NaN
# 2                                        None                     NaN
# 3                                        None                     NaN
# 4                                        None                     NaN
# ...                                       ...                     ...
# 5668                                     None                     NaN
# 5669                                     None                     NaN
# 5670                                     None                     NaN
# 5671                                     None                     NaN
# 5672                                     None                     NaN
#
#      affected_line_break affected_line_breaking_passing_option_attempted  \
# 0                   None                                            None
# 1                   None                                            None
# 2                   None                                            None
# 3                   None                                            None
# 4                   None                                            None
# ...                  ...                                             ...
# 5668                None                                            None
# 5669                None                                            None
# 5670                None                                            None
# 5671                None                                            None
# 5672                None                                            None
#
#       affected_line_breaking_passing_option_xthreat  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5668                                            NaN
# 5669                                            NaN
# 5670                                            NaN
# 5671                                            NaN
# 5672                                            NaN
#
#      affected_line_breaking_passing_option_dangerous  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 5668                                            None
# 5669                                            None
# 5670                                            None
# 5671                                            None
# 5672                                            None
#
#       affected_line_breaking_passing_option_run_subtype_id  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5668                                                NaN
# 5669                                                NaN
# 5670                                                NaN
# 5671                                                NaN
# 5672                                                NaN
#
#      affected_line_breaking_passing_option_run_subtype possession_danger  \
# 0                                                 None              None
# 1                                                 None              None
# 2                                                 None              None
# 3                                                 None              None
# 4                                                 None              None
# ...                                                ...               ...
# 5668                                              None              None
# 5669                                              None              None
# 5670                                              None              None
# 5671                                              None              None
# 5672                                              None              None
#
#      beaten_by_possession beaten_by_movement stop_possession_danger  \
# 0                    None               None                   None
# 1                    None               None                   None
# 2                    None               None                   None
# 3                    None               None                   None
# 4                    None               None                   None
# ...                   ...                ...                    ...
# 5668                 None               None                   None
# 5669                 None               None                   None
# 5670                 None               None                   None
# 5671                 None               None                   None
# 5672                 None               None                   None
#
#      reduce_possession_danger force_backward  xloss_player_possession_start  \
# 0                        None           None                            NaN
# 1                        None           None                            NaN
# 2                        None           None                            NaN
# 3                        None           None                            NaN
# 4                        None           None                            NaN
# ...                       ...            ...                            ...
# 5668                     None           None                            NaN
# 5669                     None           None                            NaN
# 5670                     None           None                            NaN
# 5671                     None           None                            NaN
# 5672                     None           None                            NaN
#
#       xloss_player_possession_end  xloss_player_possession_max  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 5668                          NaN                          NaN
# 5669                          NaN                          NaN
# 5670                          NaN                          NaN
# 5671                          NaN                          NaN
# 5672                          NaN                          NaN
#
#       xshot_player_possession_start  xshot_player_possession_end  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 5668                            NaN                          NaN
# 5669                            NaN                          NaN
# 5670                            NaN                          NaN
# 5671                            NaN                          NaN
# 5672                            NaN                          NaN
#
#       xshot_player_possession_max  is_player_possession_start_matched  \
# 0                             NaN                                True
# 1                             NaN                                True
# 2                             NaN                                True
# 3                             NaN                                True
# 4                             NaN                                True
# ...                           ...                                 ...
# 5668                          NaN                                True
# 5669                          NaN                               False
# 5670                          NaN                                True
# 5671                          NaN                                True
# 5672                          NaN                                True
#
#       is_player_possession_end_matched is_previous_pass_matched  \
# 0                                 True                     None
# 1                                 True                     True
# 2                                 True                     None
# 3                                 True                     None
# 4                                 True                     None
# ...                                ...                      ...
# 5668                              True                     True
# 5669                             False                     True
# 5670                              True                     None
# 5671                              True                     None
# 5672                              True                     None
#
#      is_pass_reception_matched fully_extrapolated
# 0                         True              False
# 1                         True              False
# 2                         True               True
# 3                         None               True
# 4                         None               True
# ...                        ...                ...
# 5668                     False              False
# 5669                      None              False
# 5670                     False              False
# 5671                      None              False
# 5672                     False              False
#
# [5673 rows x 294 columns]

# %%
match_id = 1847631
df = dynamic_dfs[f"match_{match_id}"]

# %%
df['team_in_possession_phase_type'].unique()

# %%
build_up_events = df[df['team_in_possession_phase_type'] == "Build up"]
build_up_events.head()
# Out:
# Empty DataFrame
# Columns: [event_id, index, match_id, frame_start, frame_end, frame_physical_start, time_start, time_end, minute_start, second_start, duration, period, attacking_side_id, attacking_side, event_type_id, event_type, event_subtype_id, event_subtype, player_id, player_name, player_position_id, player_position, player_in_possession_id, player_in_possession_name, player_in_possession_position_id, player_in_possession_position, team_id, team_shortname, x_start, y_start, channel_id_start, channel_start, third_id_start, third_start, penalty_area_start, x_end, y_end, channel_id_end, channel_end, third_id_end, third_end, penalty_area_end, associated_player_possession_event_id, associated_player_possession_frame_start, associated_player_possession_frame_end, associated_player_possession_end_type_id, associated_player_possession_end_type, associated_off_ball_run_event_id, associated_off_ball_run_subtype_id, associated_off_ball_run_subtype, game_state_id, game_state, team_score, opponent_team_score, phase_index, player_possession_phase_index, first_player_possession_in_team_possession, last_player_possession_in_team_possession, lead_to_different_phase, issued_from_different_phase, n_player_possessions_in_phase, team_possession_loss_in_phase, team_in_possession_phase_type_id, team_in_possession_phase_type, team_out_of_possession_phase_type_id, team_out_of_possession_phase_type, current_team_in_possession_next_phase_type_id, current_team_in_possession_next_phase_type, current_team_out_of_possession_next_phase_type_id, current_team_out_of_possession_next_phase_type, current_team_in_possession_previous_phase_type_id, current_team_in_possession_previous_phase_type, current_team_out_of_possession_previous_phase_type_id, current_team_out_of_possession_previous_phase_type, game_interruption_before_id, game_interruption_before, game_interruption_after_id, game_interruption_after, lead_to_shot, lead_to_goal, distance_covered, trajectory_angle, trajectory_direction_id, trajectory_direction, in_to_out, out_to_in, speed_avg, speed_avg_band_id, speed_avg_band, separation_start, separation_end, separation_gain, last_defensive_line_x_start, last_defensive_line_x_end, delta_to_last_defensive_line_start, delta_to_last_defensive_line_end, delta_to_last_defensive_line_gain, last_defensive_line_height_start, last_defensive_line_height_end, last_defensive_line_height_gain, ...]
# Index: []
